# %% [markdown]
# # Exploring Toronto Neighbourhoods

# %% [markdown]
#  #### Step 1: Import necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Step 2: Import data from previous exercise containing Toronto Neighbourhoods along with Latitude and Longitude

# %%
toronto_data = pd.read_csv('Toronto_Neighbourhood.csv')
toronto_data = toronto_data.drop(['index'], axis = 1)
toronto_data.head()
# Out:
#   Postcode      Borough                         Neighbourhood   Latitude  \
# 0      M1B  Scarborough                         Malvern,Rouge  43.806686
# 1      M1C  Scarborough  Rouge Hill,Highland Creek,Port Union  43.784535
# 2      M1E  Scarborough       Morningside,Guildwood,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# #### Step 3: Define the address over which we superimpose the neighbourhoods. In this case, it is Toronto

# %%
# Get the coordinates for Toronto using Geolocator

address = 'Toronto, Canada'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Step 4: Explore a neighbourhood in Toronto

# %%
#In order to do this, we need to give Foursquare credentials and version in the URL
CLIENT_ID = 'WYSINWYG' # Changed obviously, once my exercise was complete
CLIENT_SECRET = 'WYSINWYG' # your Foursquare Secret
VERSION = '20190616' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
print('In case you are not sure, WYSINWYG stands for What You See Is Not What You Get. I\'m not sharing my credentials')
print('VERSION:' + VERSION)
# Out:
# Your credentails:
# CLIENT_ID: WYSINWYG
# CLIENT_SECRET:WYSINWYG
# In case you are not sure, WYSINWYG stands for What You See Is Not What You Get. I'm not sharing my credentials
# VERSION:20190616

# %%
#As per the suggestion in the instructions, I am going to filter out only boroughs which contain the word Toronto in it
df_Toronto = toronto_data[toronto_data['Borough'].str.contains('Toronto')]
df_Toronto_data = df_Toronto.reset_index(drop=True)
df_Toronto_data
# Out:
#    Postcode           Borough  \
# 0       M4E      East Toronto
# 1       M4K      East Toronto
# 2       M4L      East Toronto
# 3       M4M      East Toronto
# 4       M4N   Central Toronto
# 5       M4P   Central Toronto
# 6       M4R   Central Toronto
# 7       M4S   Central Toronto
# 8       M4T   Central Toronto
# 9       M4V   Central Toronto
# 10      M4W  Downtown Toronto
# 11      M4X  Downtown Toronto
# 12      M4Y  Downtown Toronto
# 13      M5A  Downtown Toronto
# 14      M5B  Downtown Toronto
# 15      M5C  Downtown Toronto
# 16      M5E  Downtown Toronto
# 17      M5G  Downtown Toronto
# 18      M5H  Downtown Toronto
# 19      M5J  Downtown Toronto
# 20      M5K  Downtown Toronto
# 21      M5L  Downtown Toronto
# 22      M5N   Central Toronto
# 23      M5P   Central Toronto
# 24      M5R   Central Toronto
# 25      M5S  Downtown Toronto
# 26      M5T  Downtown Toronto
# 27      M5V  Downtown Toronto
# 28      M5W  Downtown Toronto
# 29      M5X  Downtown Toronto
# 30      M6G  Downtown Toronto
# 31      M6H      West Toronto
# 32      M6J      West Toronto
# 33      M6K      West Toronto
# 34      M6P      West Toronto
# 35      M6R      West Toronto
# 36      M6S      West Toronto
# 37      M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                         The Beaches  43.676357 -79.293031
# 1                         Riverdale,The Danforth West  43.679557 -79.352188
# 2                       The Beaches West,India Bazaar  43.668999 -79.315572
# 3                                     Studio District  43.659526 -79.340923
# 4                                       Lawrence Park  43.728020 -79.388790
# 5                                    Davisville North  43.712751 -79.390197
# 6                                  North Toronto West  43.715383 -79.405678
# 7                                          Davisville  43.704324 -79.388790
# 8                          Summerhill East,Moore Park  43.689574 -79.383160
# 9   Summerhill West,Forest Hill SE,Deer Park,South...  43.686412 -79.400049
# 10                                           Rosedale  43.679563 -79.377529
# 11                         St. James Town,Cabbagetown  43.667967 -79.367675
# 12                               Church and Wellesley  43.665860 -79.383160
# 13                           Harbourfront,Regent Park  43.654260 -79.360636
# 14                            Ryerson,Garden District  43.657162 -79.378937
# 15                                     St. James Town  43.651494 -79.375418
# 16                                        Berczy Park  43.644771 -79.373306
# 17                                 Central Bay Street  43.657952 -79.387383
# 18                             Adelaide,Richmond,King  43.650571 -79.384568
# 19    Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 20            Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 21                      Commerce Court,Victoria Hotel  43.648198 -79.379817
# 22                                           Roselawn  43.711695 -79.416936
# 23                 Forest Hill West,Forest Hill North  43.696948 -79.411307
# 24                  Yorkville,The Annex,North Midtown  43.672710 -79.405678
# 25                      University of Toronto,Harbord  43.662696 -79.400049
# 26            Kensington Market,Grange Park,Chinatown  43.653206 -79.400049
# 27  South Niagara,Bathurst Quay,King and Spadina,R...  43.628947 -79.394420
# 28                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 29              Underground city,First Canadian Place  43.648429 -79.382280
# 30                                           Christie  43.669542 -79.422564
# 31                        Dovercourt Village,Dufferin  43.669005 -79.442259
# 32                            Little Portugal,Trinity  43.647927 -79.419750
# 33         Exhibition Place,Parkdale Village,Brockton  43.636847 -79.428191
# 34                       High Park,The Junction South  43.661608 -79.464763
# 35                              Parkdale,Roncesvalles  43.648960 -79.456325
# 36                                  Swansea,Runnymede  43.651571 -79.484450
# 37  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
#For the next part of the exercise, I want to explore a part of town which contains a neighbourhood called Little Portugal, which is part of the postcode "M6J"
LP_lat = df_Toronto_data[df_Toronto_data['Postcode'] == 'M6J'].iloc[0]['Latitude']
LP_long = df_Toronto_data[df_Toronto_data['Postcode'] == 'M6J'].iloc[0]['Longitude']
print('Latitude and Longitude are :', LP_lat,  ' and ', LP_long)
# Out:
# Latitude and Longitude are : 43.647926700000006  and  -79.4197497

# %% [markdown]
# #### Step 4: The next step would be to get venues from FourSquare and check them out

# %%
# I have defined my Foursquare credentials earlier, and using the coordinates defined earlier, I will check out the venues nearby

LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LP_lat, 
    LP_long, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=53OMFYOEZQYAVD5Z1HXDG0ARMLLJYS0OIAKMTELUUO334KRO&client_secret=CZXORGV1G2AD2NENCIQKATBBXUBI5LVFHY2TCHPLWUDL33HH&v=20190616&ll=43.647926700000006,-79.4197497&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d06ad234c1f672bca2abfc7'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Trinity Bellwoods',
#   'headerFullLocation': 'Trinity Bellwoods, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 62,
#   'suggestedBounds': {'ne': {'lat': 43.65242670450001,
#     'lng': -79.41354235474367},
#    'sw': {'lat': 43.643426695500004, 'lng': -79.42595704525633}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7891c7e4b0b9643b73e08d',
#        'name': 'Bellwoods Brewery',
#        'location': {'address': '124 Ossington Ave',
#         'crossStreet': 'at Argyle St',
#         'lat': 43.647097254598236,
#         'lng': -79.41995537873463,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647097254598236,
#           'lng': -79.41995537873463}],
#         'distance': 93,
#         'postalCode': 'M6J 2Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['124 Ossington Ave (at Argyle St)',
#          'Toronto ON M6J 2Z5',
#          'Canada']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f7891c7e4b0b9643b73e08d-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50bafbe4e4b0e225612debb6',
#        'name': 'OddSeoul',
#        'location': {'address': '90 Ossington Ave.',
#         'crossStreet': 'at Humbert St',
#         'lat': 43.64619218474247,
#         'lng': -79.4196014527498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64619218474247,
#           'lng': -79.4196014527498}],
#         'distance': 193,
#         'postalCode': 'M6J 2Z4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['90 Ossington Ave. (at Humbert St)',
#          'Toronto ON M6J 2Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50bafbe4e4b0e225612debb6-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada6d36f964a520802221e3',
#        'name': 'Pizzeria Libretto',
#        'location': {'address': '221 Ossington Ave',
#         'crossStreet': 'at Dundas St W',
#         'lat': 43.64897862710277,
#         'lng': -79.4206035669193,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64897862710277,
#           'lng': -79.4206035669193}],
#         'distance': 135,
#         'postalCode': 'M6J 2Z8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['221 Ossington Ave (at Dundas St W)',
#          'Toronto ON M6J 2Z8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ada6d36f964a520802221e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '537bd61f498e0dae73728800',
#        'name': 'Bang Bang Ice Cream & Bakery',
#        'location': {'address': '93a Ossington Ave',
#         'crossStreet': 'btwn Queen and Argyle',
#         'lat': 43.64624619920086,
#         'lng': -79.41955285188536,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64624619920086,
#           'lng': -79.41955285188536}],
#         'distance': 187,
#         'postalCode': 'M6J 2Z4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['93a Ossington Ave (btwn Queen and Argyle)',
#          'Toronto ON M6J 2Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-537bd61f498e0dae73728800-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af369d0f964a52060ed21e3',
#        'name': 'Foxley Bistro',
#        'location': {'address': '207 Ossington Ave',
#         'crossStreet': 'Dundas',
#         'lat': 43.648642746283834,
#         'lng': -79.42049525794245,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648642746283834,
#           'lng': -79.42049525794245}],
#         'distance': 99,
#         'postalCode': 'M6J 2Z8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['207 Ossington Ave (Dundas)',
#          'Toronto ON M6J 2Z8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af369d0f964a52060ed21e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54e000c9498e4adcc4e449be',
#        'name': 'La Cubana',
#        'location': {'address': '92 Ossington Ave',
#         'crossStreet': 'at Humber St',
#         'lat': 43.64623003878161,
#         'lng': -79.4196356996568,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64623003878161,
#           'lng': -79.4196356996568}],
#         'distance': 189,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['92 Ossington Ave (at Humber St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d154941735',
#          'name': 'Cuban Restaurant',
#          'pluralName': 'Cuban Restaurants',
#          'shortName': 'Cuban',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54e000c9498e4adcc4e449be-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae662e8f964a520cfa621e3',
#        'name': 'Reposado',
#        'location': {'address': '136 Ossington Ave.',
#         'crossStreet': 'btwn Argyle & Foxley',
#         'lat': 43.647320789001384,
#         'lng': -79.42003151431754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647320789001384,
#           'lng': -79.42003151431754}],
#         'distance': 71,
#         'postalCode': 'M6J 2Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['136 Ossington Ave. (btwn Argyle & Foxley)',
#          'Toronto ON M6J 2Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae662e8f964a520cfa621e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53e7ff72498ec1fa4deab5d0',
#        'name': 'Mamakas Taverna',
#        'location': {'address': '80 Ossington',
#         'lat': 43.64604217335094,
#         'lng': -79.41967886278816,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64604217335094,
#           'lng': -79.41967886278816}],
#         'distance': 209,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['80 Ossington', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53e7ff72498ec1fa4deab5d0-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a91e9e7e4c4590ae9eb0a5c',
#        'name': 'Paris Paris Bar',
#        'location': {'address': '1161 Dundas St W.',
#         'lat': 43.649237,
#         'lng': -79.421436,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649237,
#           'lng': -79.421436}],
#         'distance': 199,
#         'postalCode': 'M6J 1X3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1161 Dundas St W.',
#          'Toronto ON M6J 1X3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a91e9e7e4c4590ae9eb0a5c-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae86cb3f964a5203eaf21e3',
#        'name': 'Pho Rua Vang (Golden Turtle)',
#        'location': {'address': '125 Ossington Ave.',
#         'crossStreet': 'at Argyle St.',
#         'lat': 43.64689319654605,
#         'lng': -79.41977781583955,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64689319654605,
#           'lng': -79.41977781583955}],
#         'distance': 115,
#         'postalCode': 'M6J 2Z2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['125 Ossington Ave. (at Argyle St.)',
#          'Toronto ON M6J 2Z2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae86cb3f964a5203eaf21e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2eca20f964a520b8e624e3',
#        'name': 'YogaSpace',
#        'location': {'address': '148 Ossington Avenue',
#         'crossStreet': 'Dundas',
#         'lat': 43.64760744635252,
#         'lng': -79.42013338783642,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64760744635252,
#           'lng': -79.42013338783642}],
#         'distance': 47,
#         'postalCode': 'M6J 2Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['148 Ossington Avenue (Dundas)',
#          'Toronto ON M6J 2Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2eca20f964a520b8e624e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada6d8df964a520832221e3',
#        'name': 'Union Restaurant',
#        'location': {'address': '72 Ossington Ave.',
#         'crossStreet': 'Queen St. W',
#         'lat': 43.64585979013257,
#         'lng': -79.41953208988866,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64585979013257,
#           'lng': -79.41953208988866}],
#         'distance': 230,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['72 Ossington Ave. (Queen St. W)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ada6d8df964a520832221e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da07acfbcc4a093c6fc10c9',
#        'name': 'Artscape Youngplace',
#        'location': {'address': '180 Shaw St',
#         'lat': 43.646921206418654,
#         'lng': -79.4173424662258,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646921206418654,
#           'lng': -79.4173424662258}],
#         'distance': 223,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['180 Shaw St', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da07acfbcc4a093c6fc10c9-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adfd8c0f964a520bf7d21e3',
#        'name': "The Communist's Daughter",
#        'location': {'address': '1149 Dundas St. W',
#         'crossStreet': 'at Ossington',
#         'lat': 43.64936167997857,
#         'lng': -79.42096310360856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64936167997857,
#           'lng': -79.42096310360856}],
#         'distance': 187,
#         'postalCode': 'M6J 1X4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1149 Dundas St. W (at Ossington)',
#          'Toronto ON M6J 1X4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adfd8c0f964a520bf7d21e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '585c96058d8e995f7316745c',
#        'name': 'Gift Shop',
#        'location': {'address': '89 Ossington Ave',
#         'crossStreet': 'Queen & Ossington',
#         'lat': 43.64614871682715,
#         'lng': -79.41948131634449,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64614871682715,
#           'lng': -79.41948131634449}],
#         'distance': 199,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['89 Ossington Ave (Queen & Ossington)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-585c96058d8e995f7316745c-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '585611615d6ec60f2379600d',
#        'name': 'La Banane',
#        'location': {'address': '227 Ossington Ave',
#         'lat': 43.64904020618134,
#         'lng': -79.42059946263156,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64904020618134,
#           'lng': -79.42059946263156}],
#         'distance': 141,
#         'postalCode': 'M6J 2Z8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['227 Ossington Ave',
#          'Toronto ON M6J 2Z8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-585611615d6ec60f2379600d-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae791a7f964a52079ac21e3',
#        'name': 'Lower Ossington Theatre',
#        'location': {'address': '100A Ossington Ave.',
#         'crossStreet': 'between Queen and Dundas',
#         'lat': 43.64638945106542,
#         'lng': -79.4197810126815,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64638945106542,
#           'lng': -79.4197810126815}],
#         'distance': 171,
#         'postalCode': 'M6J 2Z4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100A Ossington Ave. (between Queen and Dundas)',
#          'Toronto ON M6J 2Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '52485753'}},
#       'referralId': 'e-0-4ae791a7f964a52079ac21e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05df964a52067f620e3',
#        'name': 'Dakota Tavern',
#        'location': {'address': '249 Ossington Ave.',
#         'crossStreet': 'at Dundas St.',
#         'lat': 43.64967991705445,
#         'lng': -79.42083755592827,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64967991705445,
#           'lng': -79.42083755592827}],
#         'distance': 213,
#         'postalCode': 'M6J 3A1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['249 Ossington Ave. (at Dundas St.)',
#          'Toronto ON M6J 3A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76167830'}},
#       'referralId': 'e-0-4ad4c05df964a52067f620e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56d33fe5498e40011c23647f',
#        'name': 'Rotate This',
#        'location': {'address': '186 Ossington Ave.',
#         'lat': 43.64854360521872,
#         'lng': -79.42051802319355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64854360521872,
#           'lng': -79.42051802319355}],
#         'distance': 92,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['186 Ossington Ave.', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10d951735',
#          'name': 'Record Shop',
#          'pluralName': 'Record Shops',
#          'shortName': 'Record Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/record_shop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56d33fe5498e40011c23647f-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58081cc238fa872d3b31c0cf',
#        'name': 'Superpoint',
#        'location': {'address': '184 Ossington Ave',
#         'crossStreet': 'at Halton St',
#         'lat': 43.648438964819064,
#         'lng': -79.42051429823161,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648438964819064,
#           'lng': -79.42051429823161}],
#         'distance': 83,
#         'postalCode': 'M6J 2Z7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['184 Ossington Ave (at Halton St)',
#          'Toronto ON M6J 2Z7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58081cc238fa872d3b31c0cf-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a944817dd29c628c169cc4',
#        'name': 'Hero Heroine',
#        'location': {'address': '216 Ossington Ave',
#         'crossStreet': 'Just south of Dundas on the west side',
#         'lat': 43.64900419974215,
#         'lng': -79.42068636417389,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64900419974215,
#           'lng': -79.42068636417389}],
#         'distance': 141,
#         'postalCode': 'M6J 2Z9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['216 Ossington Ave (Just south of Dundas on the west side)',
#          'Toronto ON M6J 2Z9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110951735',
#          'name': 'Salon / Barbershop',
#          'pluralName': 'Salons / Barbershops',
#          'shortName': 'Salon / Barbershop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '60693779'}},
#       'referralId': 'e-0-51a944817dd29c628c169cc4-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad8cc7bf964a520c21421e3',
#        'name': 'Venezia Bakery',
#        'location': {'address': '114 Ossington Avenue',
#         'crossStreet': 'Argyle',
#         'lat': 43.6468112760052,
#         'lng': -79.41980345671674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6468112760052,
#           'lng': -79.41980345671674}],
#         'distance': 124,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['114 Ossington Avenue (Argyle)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad8cc7bf964a520c21421e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56119f45498efc11cc6fbfdc',
#        'name': "Bobbie Sue's Mac + Cheese",
#        'location': {'address': '162 Ossington Ave',
#         'lat': 43.64778276946676,
#         'lng': -79.42041900552132,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64778276946676,
#           'lng': -79.42041900552132}],
#         'distance': 56,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['162 Ossington Ave', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1bf941735',
#          'name': 'Mac & Cheese Joint',
#          'pluralName': 'Mac & Cheese Joints',
#          'shortName': 'Mac & Cheese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/macandcheese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56119f45498efc11cc6fbfdc-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54c46166498edeaa806cabc8',
#        'name': 'Hanmoto',
#        'location': {'address': '2 Lakeview Drive',
#         'crossStreet': 'Dundas',
#         'lat': 43.649505301973576,
#         'lng': -79.42276783144736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649505301973576,
#           'lng': -79.42276783144736}],
#         'distance': 299,
#         'postalCode': 'M5C 1X6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2 Lakeview Drive (Dundas)',
#          'Toronto ON M5C 1X6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54c46166498edeaa806cabc8-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b0b24f486bc49002c011ff9',
#        'name': 'SoSo Food Club',
#        'location': {'address': '1166 Dundas St W',
#         'lat': 43.649374803627865,
#         'lng': -79.42160177446873,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649374803627865,
#           'lng': -79.42160177446873}],
#         'distance': 219,
#         'postalCode': 'M6H 1A1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1166 Dundas St W',
#          'Toronto ON M6H 1A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b0b24f486bc49002c011ff9-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fe54620e4b067dfbe1dc838',
#        'name': 'Get Well',
#        'location': {'address': '1181 Dundas St W',
#         'lat': 43.6493204037974,
#         'lng': -79.42193705485465,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6493204037974,
#           'lng': -79.42193705485465}],
#         'distance': 234,
#         'postalCode': 'M6J 1X4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1181 Dundas St W',
#          'Toronto ON M6J 1X4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fe54620e4b067dfbe1dc838-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af302d7f964a520c4e921e3',
#        'name': 'i deal coffee',
#        'location': {'address': '162 Ossington Ave',
#         'crossStreet': 'at Foxley St',
#         'lat': 43.64784412071227,
#         'lng': -79.4202942461777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64784412071227,
#           'lng': -79.4202942461777}],
#         'distance': 44,
#         'postalCode': 'M6J 2Z7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['162 Ossington Ave (at Foxley St)',
#          'Toronto ON M6J 2Z7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af302d7f964a520c4e921e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad87544f964a520841121e3',
#        'name': 'Pho Tien Thanh',
#        'location': {'address': '57 Ossington Ave.',
#         'crossStreet': 'at Queen St. W.',
#         'lat': 43.6454840897343,
#         'lng': -79.41927617283633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6454840897343,
#           'lng': -79.41927617283633}],
#         'distance': 274,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['57 Ossington Ave. (at Queen St. W.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad87544f964a520841121e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51049684e4b06b57cac4e3e8',
#        'name': 'Bazara',
#        'location': {'address': '188 Ossington',
#         'crossStreet': 'Roylat',
#         'lat': 43.64853491212856,
#         'lng': -79.4205209529485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64853491212856,
#           'lng': -79.4205209529485}],
#         'distance': 91,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['188 Ossington (Roylat)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51049684e4b06b57cac4e3e8-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eee43b39adf257d67bf33f5',
#        'name': 'Academy Of Lions CrossFit Toronto',
#        'location': {'address': '64 Ossington Ave',
#         'lat': 43.645717362325456,
#         'lng': -79.41943732169375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.645717362325456,
#           'lng': -79.41943732169375}],
#         'distance': 247,
#         'postalCode': 'M6J 1X6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['64 Ossington Ave',
#          'Toronto ON M6J 1X6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37325322'}},
#       'referralId': 'e-0-4eee43b39adf257d67bf33f5-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '524610aa498eb8e8363a8387',
#        'name': 'Soos',
#        'location': {'address': '94 Ossington Avenue',
#         'crossStreet': 'Ossington and Argyle',
#         'lat': 43.64625487651962,
#         'lng': -79.4196494517963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64625487651962,
#           'lng': -79.4196494517963}],
#         'distance': 186,
#         'postalCode': 'M6J 2Z4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['94 Ossington Avenue (Ossington and Argyle)',
#          'Toronto ON M6J 2Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d156941735',
#          'name': 'Malay Restaurant',
#          'pluralName': 'Malay Restaurants',
#          'shortName': 'Malay',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-524610aa498eb8e8363a8387-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '572e1558498e391a0302a477',
#        'name': 'Té',
#        'location': {'address': '70 Ossington Ave',
#         'crossStreet': 'Queen St W',
#         'lat': 43.6457982128694,
#         'lng': -79.41950829388077,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6457982128694,
#           'lng': -79.41950829388077}],
#         'distance': 237,
#         'postalCode': 'M6J 2Y7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['70 Ossington Ave (Queen St W)',
#          'Toronto ON M6J 2Y7',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-572e1558498e391a0302a477-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54835826498ee8517125b280',
#        'name': 'Veghed',
#        'location': {'address': '1199 Dundas St West',
#         'crossStreet': 'Ossington',
#         'lat': 43.649224,
#         'lng': -79.422326,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649224,
#           'lng': -79.422326}],
#         'distance': 252,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1199 Dundas St West (Ossington)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54835826498ee8517125b280-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56aabee1498ebfd21c627b88',
#        'name': 'Ufficio',
#        'location': {'address': '1214 Dundas St W',
#         'crossStreet': 'at Lakeview Ave',
#         'lat': 43.649439390888254,
#         'lng': -79.42301401069709,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649439390888254,
#           'lng': -79.42301401069709}],
#         'distance': 312,
#         'postalCode': 'M6J 1X5',
#         'cc': 'CA',
#         'neighborhood': 'Dufferin Grove, Toronto, ON',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1214 Dundas St W (at Lakeview Ave)',
#          'Toronto ON M6J 1X5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56aabee1498ebfd21c627b88-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af332d9f964a520aeeb21e3',
#        'name': 'Nova Era Bakery',
#        'location': {'address': '1172 Dundas St. W',
#         'crossStreet': 'Ossington Ave.',
#         'lat': 43.64941868510166,
#         'lng': -79.42217715153669,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64941868510166,
#           'lng': -79.42217715153669}],
#         'distance': 256,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1172 Dundas St. W (Ossington Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af332d9f964a520aeeb21e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '564f3456498e9d0bc7152f88',
#        'name': "Jimmy's Coffee",
#        'location': {'address': '15 Ossington Ave',
#         'crossStreet': 'at Queen St W',
#         'lat': 43.64452074032671,
#         'lng': -79.4189080566799,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64452074032671,
#           'lng': -79.4189080566799}],
#         'distance': 385,
#         'postalCode': 'M6J 2Y8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['15 Ossington Ave (at Queen St W)',
#          'Toronto ON M6J 2Y8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-564f3456498e9d0bc7152f88-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b998cfbf964a520e68235e3',
#        'name': 'Böehmer',
#        'location': {'address': '93 Ossington Ave.',
#         'crossStreet': 'btwn Argyle & Humbert St.',
#         'lat': 43.64629266324354,
#         'lng': -79.41948952292074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64629266324354,
#           'lng': -79.41948952292074}],
#         'distance': 183,
#         'postalCode': 'M6J 2Z2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['93 Ossington Ave. (btwn Argyle & Humbert St.)',
#          'Toronto ON M6J 2Z2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b998cfbf964a520e68235e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b22e814f964a520175024e3',
#        'name': 'The Lakeview Restaurant',
#        'location': {'address': '1132 Dundas St. W',
#         'crossStreet': 'at Ossington Ave.',
#         'lat': 43.64943515996231,
#         'lng': -79.42039021958406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64943515996231,
#           'lng': -79.42039021958406}],
#         'distance': 175,
#         'postalCode': 'M6J 1X2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1132 Dundas St. W (at Ossington Ave.)',
#          'Toronto ON M6J 1X2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b22e814f964a520175024e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4b19feb32b8cfaac7c7ea0',
#        'name': 'Lost & Found',
#        'location': {'address': '44 Ossington Avenue',
#         'crossStreet': 'Queen Street',
#         'lat': 43.64937792373502,
#         'lng': -79.42414948228769,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64937792373502,
#           'lng': -79.42414948228769}],
#         'distance': 389,
#         'postalCode': 'M6J 2Y7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['44 Ossington Avenue (Queen Street)',
#          'Toronto ON M6J 2Y7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d106951735',
#          'name': "Men's Store",
#          'pluralName': "Men's Stores",
#          'shortName': "Men's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '62998766'}},
#       'referralId': 'e-0-4d4b19feb32b8cfaac7c7ea0-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bacf99ff964a52019203be3',
#        'name': 'The Tampered Press',
#        'location': {'address': '256 Crawford St.',
#         'crossStreet': 'at Dundas St. W.',
#         'lat': 43.65006186869144,
#         'lng': -79.41728020642847,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65006186869144,
#           'lng': -79.41728020642847}],
#         'distance': 309,
#         'postalCode': 'M6J 2V8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['256 Crawford St. (at Dundas St. W.)',
# ...
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6cf195f964a5204c5f2ce3-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5af9ee1eff03060039db2be2',
#        'name': 'Founder Bar',
#        'location': {'address': '1282 Dundas Street West',
#         'crossStreet': 'Dundas Street West & Dovercourt Road',
#         'lat': 43.64947797447339,
#         'lng': -79.42535203846116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64947797447339,
#           'lng': -79.42535203846116}],
#         'distance': 483,
#         'postalCode': 'M6J 1X7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1282 Dundas Street West (Dundas Street West & Dovercourt Road)',
#          'Toronto ON M6J 1X7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '494579197'}},
#       'referralId': 'e-0-5af9ee1eff03060039db2be2-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52337d3411d24d504a47b3b4',
#        'name': 'BYOB Cocktail Emporium',
#        'location': {'address': '972 Queen St W',
#         'crossStreet': 'Givins St.',
#         'lat': 43.64444685441145,
#         'lng': -79.41775729184432,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64444685441145,
#           'lng': -79.41775729184432}],
#         'distance': 419,
#         'postalCode': 'M6J 1H1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['972 Queen St W (Givins St.)',
#          'Toronto ON M6J 1H1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ff941735',
#          'name': 'Miscellaneous Shop',
#          'pluralName': 'Miscellaneous Shops',
#          'shortName': 'Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '135067206'}},
#       'referralId': 'e-0-52337d3411d24d504a47b3b4-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b491d0df964a520686626e3',
#        'name': 'El Almacen Yerba Mate Cafe + Gallery',
#        'location': {'address': '1078 Queen St W',
#         'crossStreet': 'at Dovercourt Rd',
#         'lat': 43.64368185408237,
#         'lng': -79.42162671323418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64368185408237,
#           'lng': -79.42162671323418}],
#         'distance': 496,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1078 Queen St W (at Dovercourt Rd)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b491d0df964a520686626e3-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548b737b498ecb54daabf7dd',
#        'name': 'Hanji',
#        'location': {'address': '940 Queen Street W',
#         'crossStreet': 'Shaw St',
#         'lat': 43.644664910209585,
#         'lng': -79.41642916229416,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.644664910209585,
#           'lng': -79.41642916229416}],
#         'distance': 450,
#         'postalCode': 'M6J 1G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['940 Queen Street W (Shaw St)',
#          'Toronto ON M6J 1G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d128951735',
#          'name': 'Gift Shop',
#          'pluralName': 'Gift Shops',
#          'shortName': 'Gift Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548b737b498ecb54daabf7dd-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d31ecf26c7c721e40e7aa56',
#        'name': 'Trinity Bellwoods Dog Park - The Bowl',
#        'location': {'address': '1053 Dundas St W',
#         'lat': 43.64862507107537,
#         'lng': -79.4144429897052,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64862507107537,
#           'lng': -79.4144429897052}],
#         'distance': 434,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1053 Dundas St W', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'shortName': 'Dog Run',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d31ecf26c7c721e40e7aa56-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '545d6eeb498ea42297425c1e',
#        'name': 'Bar Fancy',
#        'location': {'address': '1070 Queen Street West',
#         'crossStreet': 'Dovercourt',
#         'lat': 43.64373383144182,
#         'lng': -79.4213257341413,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64373383144182,
#           'lng': -79.4213257341413}],
#         'distance': 483,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1070 Queen Street West (Dovercourt)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-545d6eeb498ea42297425c1e-54'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05df964a5204bf620e3',
#        'name': 'Fresh',
#        'location': {'address': '894 Queen St. W',
#         'crossStreet': 'at Crawford',
#         'lat': 43.64500965327651,
#         'lng': -79.41508361054778,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64500965327651,
#           'lng': -79.41508361054778}],
#         'distance': 496,
#         'postalCode': 'M6J 1G3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['894 Queen St. W (at Crawford)',
#          'Toronto ON M6J 1G3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05df964a5204bf620e3-55'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59c44b93b3c9613aae5de8fb',
#        'name': 'Mahjong Bar',
#        'location': {'address': '1276 Dundas St. West',
#         'lat': 43.64952459972479,
#         'lng': -79.4250960892669,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64952459972479,
#           'lng': -79.4250960892669}],
#         'distance': 465,
#         'postalCode': 'M6J 1X7',
#         'cc': 'CA',
#         'neighborhood': 'Dufferin Grove',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1276 Dundas St. West',
#          'Toronto ON M6J 1X7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59c44b93b3c9613aae5de8fb-56'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f61622ce4b0ed01576448ad',
#        'name': "Bambi's",
#        'location': {'address': '1265 Dundas St W',
#         'crossStreet': 'Dovercourt',
#         'lat': 43.64930284698693,
#         'lng': -79.42459088452479,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64930284698693,
#           'lng': -79.42459088452479}],
#         'distance': 418,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1265 Dundas St W (Dovercourt)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f61622ce4b0ed01576448ad-57'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5154f168e4b0d1b01edb977e',
#        'name': 'Carmen',
#        'location': {'address': '922 Queen St. W',
#         'crossStreet': 'at Shaw St.',
#         'lat': 43.644829338661474,
#         'lng': -79.41587230493745,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.644829338661474,
#           'lng': -79.41587230493745}],
#         'distance': 465,
#         'postalCode': 'M5T 2L9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['922 Queen St. W (at Shaw St.)',
#          'Toronto ON M5T 2L9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5154f168e4b0d1b01edb977e-58'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7dfa0fe5e871fe304ad004',
#        'name': 'The County General',
#        'location': {'address': '936 Queen St W',
#         'crossStreet': 'at Shaw St',
#         'lat': 43.64475517040364,
#         'lng': -79.41625699799329,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64475517040364,
#           'lng': -79.41625699799329}],
#         'distance': 451,
#         'postalCode': 'M6J 1G6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['936 Queen St W (at Shaw St)',
#          'Toronto ON M6J 1G6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7dfa0fe5e871fe304ad004-59'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527f0765498e3c9924292d6d',
#        'name': 'The Dock Ellis',
#        'location': {'address': '1280 Dundas West',
#         'crossStreet': 'Dovercourt',
#         'lat': 43.64945688097198,
#         'lng': -79.42529715531316,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64945688097198,
#           'lng': -79.42529715531316}],
#         'distance': 478,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1280 Dundas West (Dovercourt)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-527f0765498e3c9924292d6d-60'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b79f533f964a520881c2fe3',
#        'name': 'Fred Perry Toronto',
#        'location': {'address': '964 Queen Street West',
#         'crossStreet': 'Ossington',
#         'lat': 43.64448271279942,
#         'lng': -79.41720025480164,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64448271279942,
#           'lng': -79.41720025480164}],
#         'distance': 434,
#         'postalCode': 'M6J 1G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['964 Queen Street West (Ossington)',
#          'Toronto ON M6J 1G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d106951735',
#          'name': "Men's Store",
#          'pluralName': "Men's Stores",
#          'shortName': "Men's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b79f533f964a520881c2fe3-61'}]}]}}

# %%
#The next steps are similar to the videos about neighbourhoods in NYC

#This functione extracts the category of the venues
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#We convert the data into a dataframe from the Json, which is not very helpful for reading
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                            name         categories        lat        lng
# 0             Bellwoods Brewery            Brewery  43.647097 -79.419955
# 1                      OddSeoul  Korean Restaurant  43.646192 -79.419601
# 2             Pizzeria Libretto        Pizza Place  43.648979 -79.420604
# 3  Bang Bang Ice Cream & Bakery     Ice Cream Shop  43.646246 -79.419553
# 4                 Foxley Bistro   Asian Restaurant  43.648643 -79.420495

# %%
#Now, let's check how many venues were returned by FourSquare to begin with
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 62 venues were returned by Foursquare.
